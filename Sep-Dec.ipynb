# %%
import pandas as pd
import numpy as np

sept_dfs = []

sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_1.csv'))
sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_2.csv'))
sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_3.csv'))
sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_4.csv'))
sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_5.csv'))

sept = pd.concat(sept_dfs)
sept.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1403907321.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1403907321.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1403907321.py:8: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sept_dfs.append(pd.read_csv('2024 BIKE DATA/202409-citibike-tripdata/202409-citibike-tripdata_3.csv'))
# ...

# %%
oct_dfs = []

oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_1.csv'))
oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_2.csv'))
oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_3.csv'))
oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_4.csv'))
oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_5.csv'))
oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_6.csv'))

oct = pd.concat(oct_dfs)
oct.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1420223056.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1420223056.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1420223056.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct_dfs.append(pd.read_csv('2024 BIKE DATA/202410-citibike-tripdata/202410-citibike-tripdata_3.csv'))
# ...

# %%
nov_dfs = []

nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_1.csv'))
nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_2.csv'))
nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_3.csv'))
nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_4.csv'))

nov = pd.concat(nov_dfs)
nov.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/3591797860.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/3591797860.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/3591797860.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov_dfs.append(pd.read_csv('2024 BIKE DATA/202411-citibike-tripdata/202411-citibike-tripdata_3.csv'))
# ...

# %%
dec_dfs = []

dec_dfs.append(pd.read_csv('2024 BIKE DATA/202412-citibike-tripdata/202412-citibike-tripdata_1.csv'))
dec_dfs.append(pd.read_csv('2024 BIKE DATA/202412-citibike-tripdata/202412-citibike-tripdata_2.csv'))
dec_dfs.append(pd.read_csv('2024 BIKE DATA/202412-citibike-tripdata/202412-citibike-tripdata_3.csv'))

dec = pd.concat(dec_dfs)
dec.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1565483944.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec_dfs.append(pd.read_csv('2024 BIKE DATA/202412-citibike-tripdata/202412-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8716/1565483944.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec_dfs.append(pd.read_csv('2024 BIKE DATA/202412-citibike-tripdata/202412-citibike-tripdata_2.csv'))
#             ride_id  rideable_type               started_at  \
# 0  B44E5B10AEE58AD0   classic_bike  2024-12-14 10:58:18.153
# 1  BC252DC6A6011556  electric_bike  2024-12-12 14:46:12.473
# 2  6FBE55EF6FE8736D  electric_bike  2024-12-11 07:55:18.770
# 3  908890DE7FDCF9FE  electric_bike  2024-12-09 22:51:11.668
# 4  D5D366379A4DC0A8   classic_bike  2024-12-10 18:48:40.063
#
# ...
