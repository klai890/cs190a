# %%
import pandas as pd
import numpy as np

jan = pd.read_csv('2024 BIKE DATA/202401-citibike-tripdata.csv')
feb = pd.read_csv('2024 BIKE DATA/202402-citibike-tripdata.csv')
march = pd.read_csv('2024 BIKE DATA/202403-citibike-tripdata.csv')
april = pd.read_csv('2024 BIKE DATA/202404-citibike-tripdata.csv')
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/66549666.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan = pd.read_csv('2024 BIKE DATA/202401-citibike-tripdata.csv')
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/66549666.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb = pd.read_csv('2024 BIKE DATA/202402-citibike-tripdata.csv')
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/66549666.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   march = pd.read_csv('2024 BIKE DATA/202403-citibike-tripdata.csv')
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/66549666.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
jan.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  5078F3D302000BD2  electric_bike  2024-01-22 18:43:19.012
# 1  814337105D37302A  electric_bike  2024-01-11 19:19:18.721
# 2  A33A920E2B10710C  electric_bike  2024-01-30 19:17:41.693
# 3  A3A5FC0DD7D34D74  electric_bike  2024-01-27 11:27:01.759
# 4  6F96728ECEFBDAA4  electric_bike  2024-01-16 15:15:41.000
#
#                   ended_at                  start_station_name  \
# 0  2024-01-22 18:48:10.708  Frederick Douglass Blvd & W 145 St
# 1  2024-01-11 19:47:36.007                     W 54 St & 6 Ave
# 2  2024-01-30 19:32:49.857                     E 11 St & Ave B
# 3  2024-01-27 11:38:01.213                     W 54 St & 6 Ave
# 4  2024-01-16 15:29:26.156               Madison Ave & E 99 St
#
#   start_station_id            end_station_name end_station_id  start_lat  \
# 0          7954.12  St Nicholas Ave & W 126 St        7756.10  40.823072
# 1          6771.13             E 74 St & 1 Ave        6953.08  40.761822
# ...

# %%
jan.info()
jan.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1888085 entries, 0 to 1888084
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 187.3+ MB
#           start_lat     start_lng       end_lat       end_lng
# count  1.888085e+06  1.888085e+06  1.887534e+06  1.887534e+06
# mean   4.073898e+01 -7.397188e+01  4.073888e+01 -7.397208e+01
# std    4.003527e-02  2.818343e-02  3.990145e-02  2.816227e-02
# ...

# %%
may_dfs = []

may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_1.csv'))
may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_2.csv'))
may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_3.csv'))
may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_4.csv'))
may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_5.csv'))

may = pd.concat(may_dfs)
may.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/912083189.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/912083189.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/912083189.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   may_dfs.append(pd.read_csv('2024 BIKE DATA/202405-citibike-tripdata/202405-citibike-tripdata_3.csv'))
# ...

# %%
june_dfs = []

june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_1.csv'))
june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_2.csv'))
june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_3.csv'))
june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_4.csv'))
june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_5.csv'))

june = pd.concat(june_dfs)
june.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/820852239.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/820852239.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/820852239.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   june_dfs.append(pd.read_csv('2024 BIKE DATA/202406-citibike-tripdata/202406-citibike-tripdata_3.csv'))
# ...

# %%
july_dfs = []

july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_1.csv'))
july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_2.csv'))
july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_3.csv'))
july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_4.csv'))
july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_5.csv'))

july = pd.concat(july_dfs)
july.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/3223159967.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/3223159967.py:4: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/3223159967.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   july_dfs.append(pd.read_csv('2024 BIKE DATA/202407-citibike-tripdata/202407-citibike-tripdata_3.csv'))
# ...

# %%
august_dfs = []

august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_1.csv'))
august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_2.csv'))
august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_3.csv'))
august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_4.csv'))
august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_5.csv'))

august = pd.concat(august_dfs)
august.head()
# Out:
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/223960614.py:3: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_1.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/223960614.py:4: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_2.csv'))
# /var/folders/lz/kzff5gf543sbfrp4_42hxgwc0000gn/T/ipykernel_8609/223960614.py:5: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   august_dfs.append(pd.read_csv('2024 BIKE DATA/202408-citibike-tripdata/202408-citibike-tripdata_3.csv'))
# ...

# %%
null_values = jan.isnull()
null_counts = jan.isnull().sum()

print(null_values)
print(null_counts)
# Out:
#          ride_id  rideable_type  started_at  ended_at  start_station_name  \
# 0          False          False       False     False               False
# 1          False          False       False     False               False
# 2          False          False       False     False               False
# 3          False          False       False     False               False
# 4          False          False       False     False               False
# ...          ...            ...         ...       ...                 ...
# 1888080    False          False       False     False               False
# 1888081    False          False       False     False               False
# 1888082    False          False       False     False               False
# 1888083    False          False       False     False               False
# 1888084    False          False       False     False               False
#
#          start_station_id  end_station_name  end_station_id  start_lat  \
# ...
